# %% [markdown]
# # pPXF: Fitting integral-field data at high redshift
#
# Usage example for the procedure pPXF originally described in [Cappellari &
# Emsellem (2004)](http://adsabs.harvard.edu/abs/2004PASP..116..138C),
# substantially upgraded in [Cappellari
# (2017)](http://adsabs.harvard.edu/abs/2017MNRAS.466..798C) and with the
# inclusion of photometry and linear constraints in [Cappellari
# (2023)](https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C).
#
# * V1.0.0: Michele Cappellari, Oxford, 5 June 2024
#
#
# ![pPXF Logo](https://www-astro.physics.ox.ac.uk/~cappellari/software/ppxf_logo.svg)

# %%
from pathlib import Path
from urllib import request

import numpy as np
from astropy.io import fits
from scipy import signal, ndimage
import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from vorbin.voronoi_2d_binning import voronoi_2d_binning
from plotbin.plot_velfield import plot_velfield

# %% [markdown]
# ## Function definitions

# %%
class read_muse_cube:
    def __init__(self, filename, wave_range, redshift, sn_min=1):
        """
        Read MUSE cube, log rebin it and compute coordinates of each spaxel.
        Median FWHM resolution = 2.62Å. Range: 2.51--2.88 (ESO instrument
        manual). 

        IMPORTANT: the details of this function depend on the way the data were
        stored in the FITS file and the available keywords in the FITS header.
        One may have to adapt the function to properly read the FITS file under
        analysis.
        
        """
        hdu = fits.open(filename)
        head = hdu[1].header
        cube = hdu[1].data  
        cuberr = hdu[2].data 

        # Only use the specified rest-frame wavelength range
        wave = head['CRVAL3'] + head['CD3_3']*np.arange(cube.shape[0])
        wave /= (1 + redshift)      # de-redshift the spectrum
        w = (wave > wave_range[0]) & (wave < wave_range[1])
        wave = wave[w]
        cube = cube[w, ...]
        cuberr = cuberr[w, ...]

        signal = np.nanmedian(cube, 0)
        noise = np.sqrt(np.nanmedian(cuberr, 0))

        # Create coordinates centred on the brightest spaxel
        jm = np.argmax(signal)
        row, col = map(np.ravel, np.indices(cube.shape[-2:]))
        pixsize = abs(head["CD2_2"])*3600    # 0.2"
        x = (col - col[jm])*pixsize
        y = (row - row[jm])*pixsize

        # Transform cube into 2-dim array of spectra
        npix = cube.shape[0]
        spectra = cube.reshape(npix, -1) # create array of spectra [npix, nx*ny]
        variance = cuberr.reshape(npix, -1) # create array of spectra [npix, nx*ny]

        c = 299792.458  # speed of light in km/s
        velscale = np.min(c*np.diff(np.log(wave)))  # Preserve smallest velocity step
        lam_range_temp = [np.min(wave), np.max(wave)]
        spectra, ln_lam_gal, velscale = util.log_rebin(lam_range_temp, spectra, velscale=velscale)

        good = select_galay_spaxels(signal/noise, sn_min)

        self.velscale = velscale
        self.spectra = spectra[:, good]
        self.variance = variance[:, good]
        self.signal_all = signal.ravel()
        self.x_all = x
        self.y_all = y
        self.good = good
        self.x = x[good]
        self.y = y[good]
        self.signal = signal.flat[good]
        self.noise = noise.flat[good]
        self.col = col + 1   # start counting from 1
        self.row = row + 1
        self.ln_lam_gal = ln_lam_gal
        self.fwhm_gal = 2.62/(1 + redshift)  # Median FWHM resolution of MUSE

###############################################################################

def select_galay_spaxels(sn, sn_min):
    """Returns indices of connected spaxels with S/N > sn_min"""

    # Extract indices of connected spaxels with S/N > sn_min
    mask = signal.medfilt(sn, 3) > sn_min
    labels, nb = ndimage.label(mask)   # Get blob indices
    sizes = ndimage.sum(mask, labels, np.arange(nb + 1))
    j = np.argsort(sizes)[-1]      # find the largest blob
    
    return np.flatnonzero(labels == j)

###############################################################################

def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma
    in relative error until the bad bins don't change any more.
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

###############################################################################

def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers.
    """
    print('#'*78)
    mask = mask0.copy()
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask)

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask)
    
    optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)

    if plot:
        plt.subplot(122)
        pp.plot()

    return pp, optimal_template, sn

###############################################################################

# %% [markdown]
# ## Data input and Voronoi binning
#
# Load the MUSE data cube

# %%
lam_range_temp = [3540, 5500]   
galname = 'MACS1206_7876.fits'
redshift = 0.43     # Initial redshift estimate
sn_min = 0.5        # This is to remove residuals-dominated spectra before Voronoi binning

s = read_muse_cube(galname, lam_range_temp, redshift, sn_min)

# %% [markdown]
# Spatially Voronoi bin the data to a target $S/N=5$ per bin using the [VorBin](https://pypi.org/project/vorbin/) method and software of [Cappellari & Copin (2003)](https://ui.adsabs.harvard.edu/abs/2003MNRAS.342..345C/abstract)

# %%
target_sn = 5
bin_num = voronoi_2d_binning(s.x, s.y, s.signal, s.noise, target_sn, plot=1, quiet=1)[0]
plt.tight_layout()

# %% [markdown]
# ## Templates library
#
# Select a template library by uncommenting one of the ``sps_name`` variables below

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

sps = lib.sps_lib(filename, s.velscale, s.fwhm_gal)
stars_templates = sps.templates
# Out:
# WARNING: Template's resolution dlam is larger than galaxy's at some wavelengths.This is not necessarily a problem as these may be outside the fitted range.

# %% [markdown]
# ## pPXF Fit to global spectrum

# %%
start = [0, 200.]  # (km/s), starting guess for [V,sigma]
mask0 = s.ln_lam_gal > 0    # Do not use an initial mask in this case. This could be used to mask known emission lines
lam_gal = np.exp(s.ln_lam_gal)

# %% [markdown]
# If `optimal_template` is set to 1, a single template is created using the average global spectrum of the galaxy. This single template is then employed to fit the kinematics across all Voronoi bins. On the other hand, if `optimal_template` is set to 0, the entire library of SPS templates is fitted to each Voronoi bin individually. Opting for a single optimal template is generally more robust for data with low signal-to-noise ratios (S/N), but it can introduce bias when there are very strong population gradients. Although, in most scenarios, the results should not differ significantly between the two approaches.

# %%
single_template = True
if single_template:
    galaxy = np.nansum(s.spectra[:, s.signal/s.noise > 5], 1)   # Global spectrum
    pp, optimal_template, sn = ppxf_fit_and_clean(
            stars_templates, galaxy, s.velscale, start, mask0, lam_gal, sps.lam_temp)
    txt = f"Global Spectrum; $\\sigma$={pp.sol[1]:.0f} (km/s); S/N={sn:.1f}"
    print(txt)
    plt.title(txt)
else:
    optimal_template = stars_templates
# Out:
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:        14       189
# chi2/DOF: 557.5; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:         9       186
# chi2/DOF: 183.9; DOF: 2710; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
# Global Spectrum; $\sigma$=186 (km/s); S/N=33.8

# %% [markdown]
# ## pPXF fit to all Voronoi bins
#
# Fit the kinematics of all Voronoi bins. Also store the centroid of the Voronoi bins for plotting.

# %%
nbins = np.unique(bin_num).size
velbin, sigbin, xbin, ybin = np.zeros((4, nbins))

for j in range(nbins):
    plot = True if j < 3 else False  # Only plot the first few spectra
    w = bin_num == j
    galaxy = np.nanmean(s.spectra[:, w], 1)
    pp, _, sn = ppxf_fit_and_clean(
        optimal_template, galaxy, s.velscale, start, mask0, lam_gal, sps.lam_temp, plot=plot)
    velbin[j], sigbin[j] = pp.sol
    xbin[j], ybin[j] = np.mean(s.x[w]), np.mean(s.y[w])

    txt = f"Voronoi bin {j + 1} / {nbins}; $\\sigma$={sigbin[j]:.0f} (km/s); S/N={sn:.1f}"
    print(txt)
    if plot:
        plt.title(txt)
# Out:
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:        30       196
# chi2/DOF: 6.319; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0959
#  Best Fit:       Vel     sigma
#  comp.  0:        31       197
# chi2/DOF: 5.131; DOF: 2742; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0965
# Voronoi bin 1 / 38; $\sigma$=197 (km/s); S/N=18.9
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:        51       151
# chi2/DOF: 5.025; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0534
#  Best Fit:       Vel     sigma
#  comp.  0:        48       150
# chi2/DOF: 4.024; DOF: 2730; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0539
# Voronoi bin 2 / 38; $\sigma$=150 (km/s); S/N=12.9
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:        91       169
# chi2/DOF: 4.378; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0518
#  Best Fit:       Vel     sigma
#  comp.  0:        93       169
# chi2/DOF: 3.751; DOF: 2748; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0513
# Voronoi bin 3 / 38; $\sigma$=169 (km/s); S/N=12.3
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:        68       174
# chi2/DOF: 5.287; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0701
#  Best Fit:       Vel     sigma
#  comp.  0:        65       172
# chi2/DOF: 4.571; DOF: 2743; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0697
# Voronoi bin 4 / 38; $\sigma$=172 (km/s); S/N=14.8
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       152       151
# chi2/DOF: 3.267; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0197
#  Best Fit:       Vel     sigma
#  comp.  0:       147       152
# chi2/DOF: 1.786; DOF: 2724; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0195
# Voronoi bin 5 / 38; $\sigma$=152 (km/s); S/N=7.3
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:        59       152
# chi2/DOF: 3.155; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0173
#  Best Fit:       Vel     sigma
#  comp.  0:        59       157
# chi2/DOF: 1.823; DOF: 2730; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0175
# Voronoi bin 6 / 38; $\sigma$=157 (km/s); S/N=6.4
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       129       133
# chi2/DOF: 4.730; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0359
#  Best Fit:       Vel     sigma
#  comp.  0:       128       137
# chi2/DOF: 3.567; DOF: 2730; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#      0.036
# Voronoi bin 7 / 38; $\sigma$=137 (km/s); S/N=8.7
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       110       157
# chi2/DOF: 2.724; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0255
#  Best Fit:       Vel     sigma
#  comp.  0:       106       155
# chi2/DOF: 1.826; DOF: 2739; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0256
# Voronoi bin 8 / 38; $\sigma$=155 (km/s); S/N=8.9
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       187       102
# chi2/DOF: 3.344; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0153
#  Best Fit:       Vel     sigma
#  comp.  0:       182       104
# chi2/DOF: 0.8959; DOF: 2730; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0152
# Voronoi bin 9 / 38; $\sigma$=104 (km/s); S/N=8.3
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       177        40
# chi2/DOF: 1.522; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0027
#  Best Fit:       Vel     sigma
#  comp.  0:       163       115
# chi2/DOF: 0.3367; DOF: 2679; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#    0.00271
# Voronoi bin 10 / 38; $\sigma$=115 (km/s); S/N=3.1
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       178        99
# chi2/DOF: 1.816; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0116
#  Best Fit:       Vel     sigma
#  comp.  0:       175        98
# chi2/DOF: 1.081; DOF: 2720; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0118
# Voronoi bin 11 / 38; $\sigma$=98 (km/s); S/N=5.5
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       166        22
# chi2/DOF: 0.9545; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0022
#  Best Fit:       Vel     sigma
#  comp.  0:       161       120
# chi2/DOF: 0.3458; DOF: 2698; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#    0.00216
# Voronoi bin 12 / 38; $\sigma$=120 (km/s); S/N=2.5
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       132       136
# chi2/DOF: 1.196; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#    0.00324
#  Best Fit:       Vel     sigma
#  comp.  0:       122       119
# chi2/DOF: 0.3790; DOF: 2709; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#    0.00287
# Voronoi bin 13 / 38; $\sigma$=119 (km/s); S/N=3.3
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:         3       164
# chi2/DOF: 5.248; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0346
#  Best Fit:       Vel     sigma
#  comp.  0:         4       163
# chi2/DOF: 3.288; DOF: 2731; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0349
# Voronoi bin 14 / 38; $\sigma$=163 (km/s); S/N=9.3
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       -19       145
# chi2/DOF: 1.792; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#    0.00714
#  Best Fit:       Vel     sigma
#  comp.  0:       -26       145
# chi2/DOF: 0.5881; DOF: 2714; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#    0.00733
# Voronoi bin 15 / 38; $\sigma$=145 (km/s); S/N=4.4
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       -13       164
# chi2/DOF: 5.718; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0603
#  Best Fit:       Vel     sigma
#  comp.  0:       -13       166
# chi2/DOF: 4.167; DOF: 2736; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0604
# Voronoi bin 16 / 38; $\sigma$=166 (km/s); S/N=13.3
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       -91        24
# chi2/DOF: 0.8031; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#    0.00196
#  Best Fit:       Vel     sigma
#  comp.  0:       -99        28
# chi2/DOF: 0.3838; DOF: 2687; degree = 4; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 24; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#      0.002
# Voronoi bin 17 / 38; $\sigma$=28 (km/s); S/N=2.4
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       -22       175
# chi2/DOF: 3.340; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0207
#  Best Fit:       Vel     sigma
#  comp.  0:       -23       175
# chi2/DOF: 1.796; DOF: 2725; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0205
# Voronoi bin 18 / 38; $\sigma$=175 (km/s); S/N=6.6
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       -44       157
# chi2/DOF: 6.091; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0645
#  Best Fit:       Vel     sigma
#  comp.  0:       -41       158
# chi2/DOF: 4.661; DOF: 2736; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0649
# Voronoi bin 19 / 38; $\sigma$=158 (km/s); S/N=13.6
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:        -5       180
# chi2/DOF: 5.417; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0852
#  Best Fit:       Vel     sigma
#  comp.  0:        -4       181
# chi2/DOF: 4.683; DOF: 2742; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0849
# Voronoi bin 20 / 38; $\sigma$=181 (km/s); S/N=17.4
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       -92       130
# chi2/DOF: 4.491; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0324
#  Best Fit:       Vel     sigma
#  comp.  0:       -88       129
# chi2/DOF: 3.368; DOF: 2735; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0328
# Voronoi bin 21 / 38; $\sigma$=129 (km/s); S/N=9.2
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:        24       177
# chi2/DOF: 5.289; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0616
#  Best Fit:       Vel     sigma
#  comp.  0:        24       175
# chi2/DOF: 4.308; DOF: 2742; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0614
# Voronoi bin 22 / 38; $\sigma$=175 (km/s); S/N=13.2
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:      -106       107
# chi2/DOF: 2.801; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0108
#  Best Fit:       Vel     sigma
#  comp.  0:      -107       107
# chi2/DOF: 1.751; DOF: 2734; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0108
# Voronoi bin 23 / 38; $\sigma$=107 (km/s); S/N=4.2
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       -72       150
# chi2/DOF: 5.629; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0406
#  Best Fit:       Vel     sigma
#  comp.  0:       -76       150
# chi2/DOF: 3.472; DOF: 2728; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0404
# Voronoi bin 24 / 38; $\sigma$=150 (km/s); S/N=10.2
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       -45       171
# chi2/DOF: 2.767; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0306
#  Best Fit:       Vel     sigma
#  comp.  0:       -48       161
# chi2/DOF: 1.864; DOF: 2729; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0305
# Voronoi bin 25 / 38; $\sigma$=161 (km/s); S/N=10.3
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:      -123       125
# chi2/DOF: 4.384; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0293
#  Best Fit:       Vel     sigma
#  comp.  0:      -122       129
# chi2/DOF: 3.321; DOF: 2731; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0296
# Voronoi bin 26 / 38; $\sigma$=129 (km/s); S/N=7.9
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:        61       157
# chi2/DOF: 3.938; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0243
#  Best Fit:       Vel     sigma
#  comp.  0:        56       152
# chi2/DOF: 2.901; DOF: 2732; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0237
# Voronoi bin 27 / 38; $\sigma$=152 (km/s); S/N=7.1
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       -27       153
# chi2/DOF: 2.383; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0208
#  Best Fit:       Vel     sigma
#  comp.  0:       -33       153
# chi2/DOF: 1.704; DOF: 2733; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0206
# Voronoi bin 28 / 38; $\sigma$=153 (km/s); S/N=7.0
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:        76       100
# chi2/DOF: 0.8344; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#    0.00325
#  Best Fit:       Vel     sigma
#  comp.  0:        62       100
# chi2/DOF: 0.4093; DOF: 2719; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#    0.00324
# Voronoi bin 29 / 38; $\sigma$=100 (km/s); S/N=3.3
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:      -142        94
# chi2/DOF: 2.079; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0134
#  Best Fit:       Vel     sigma
#  comp.  0:      -141       104
# chi2/DOF: 1.734; DOF: 2740; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0133
# Voronoi bin 30 / 38; $\sigma$=104 (km/s); S/N=4.6
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:        47         0
# chi2/DOF: 0.8086; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#      0.005
#  Best Fit:       Vel     sigma
#  comp.  0:        47        35
# chi2/DOF: 0.5601; DOF: 2723; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#    0.00506
# Voronoi bin 31 / 38; $\sigma$=35 (km/s); S/N=3.9
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       -92       110
# chi2/DOF: 2.413; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0141
#  Best Fit:       Vel     sigma
#  comp.  0:       -84       106
# chi2/DOF: 1.702; DOF: 2734; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0144
# Voronoi bin 32 / 38; $\sigma$=106 (km/s); S/N=5.2
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       -32       120
# chi2/DOF: 0.8104; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#    0.00336
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        91
# chi2/DOF: 0.3568; DOF: 2709; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#    0.00329
# Voronoi bin 33 / 38; $\sigma$=91 (km/s); S/N=2.8
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:      -157       146
# chi2/DOF: 2.203; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0153
#  Best Fit:       Vel     sigma
#  comp.  0:      -151       142
# chi2/DOF: 1.521; DOF: 2722; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0152
# Voronoi bin 34 / 38; $\sigma$=142 (km/s); S/N=5.8
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       194        92
# chi2/DOF: 0.7554; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#    0.00384
#  Best Fit:       Vel     sigma
#  comp.  0:       207        86
# chi2/DOF: 0.3360; DOF: 2711; degree = 4; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#    0.00363
# Voronoi bin 35 / 38; $\sigma$=86 (km/s); S/N=3.0
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:      -146       108
# chi2/DOF: 1.957; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0108
#  Best Fit:       Vel     sigma
#  comp.  0:      -164        85
# chi2/DOF: 1.133; DOF: 2726; degree = 4; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#     0.0106
# Voronoi bin 36 / 38; $\sigma$=85 (km/s); S/N=4.8
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:       -53       120
# chi2/DOF: 0.8728; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#    0.00302
#  Best Fit:       Vel     sigma
#  comp.  0:       -76       109
# chi2/DOF: 0.2149; DOF: 2685; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#    0.00295
# Voronoi bin 37 / 38; $\sigma$=109 (km/s); S/N=3.1
# ##############################################################################
#  Best Fit:       Vel     sigma
#  comp.  0:      -128        87
# chi2/DOF: 0.8274; DOF: 2769; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#    0.00371
#  Best Fit:       Vel     sigma
#  comp.  0:      -138       103
# chi2/DOF: 0.3075; DOF: 2693; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/1
# Templates weights:
#    0.00372
# Voronoi bin 38 / 38; $\sigma$=103 (km/s); S/N=3.4

# %% [markdown]
# Plot the output kinematics maps

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
plt.subplots_adjust(wspace=0.5)

plt.subplot(121)
velbin -= np.median(velbin)
vmax = np.percentile(abs(velbin), 95)
plt.tricontour(s.x_all, s.y_all, -2.5*np.log10(s.signal_all/np.max(s.signal_all)), levels=np.arange(20), linewidths=1);  # 1 mag contours
plot_velfield(xbin, ybin, velbin, colorbar=1, cmap='sauron', label='V (km/s)', vmin=-vmax, vmax=vmax)
plt.title(Path(galname).stem)

plt.subplot(122)
vmin, vmax = np.percentile(sigbin, [5, 95])
plt.tricontour(s.x_all, s.y_all, -2.5*np.log10(s.signal_all/np.max(s.signal_all)), levels=np.arange(20), linewidths=1);  # 1 mag contours
plot_velfield(xbin, ybin, sigbin, colorbar=1, cmap='inferno', label=r'$\sigma$ (km/s)', vmin=vmin, vmax=vmax)
plt.title(Path(galname).stem);
